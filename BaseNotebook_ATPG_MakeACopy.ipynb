# %% [markdown]
# <a href="https://colab.research.google.com/github/david-levin11/Verification_Notebooks/blob/main/BaseNotebook_ATPG_MakeACopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Title--Please Make a Copy of this Notebook Prior To Editing!**
# <br/>
# Description--Write your description of what the notebook will do and any pitfalls or caveats here.
#
# - David Levin, Arctic Testbed & Proving Ground, Anchorage Alaska

# %% [markdown]
# ##**1 - Install CondaColab**
# This will manage the installation of the packages we need.<br />**NOTE**: this will restart the notebook, and you will get a crash popup in the lower-left corner that you can safely ignore

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:20
# 🔁 Restarting kernel...

# %% [markdown]
# ##**2 - Install and Import Packages**
# This will take about a minute to run.

# %%
# !mamba install -q -c "required python packages here (ex: xarray pandas matplotlib)"
# Out:
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#  ╭─────────────────────────────────────────────────╮
#  │ I'm building Herbie's default config file.      │
#  ╰╥────────────────────────────────────────────────╯
#  👷🏻‍♂️
#  ╭─────────────────────────────────────────────────╮
#  │ You're ready to go.                             │
#  │ You may edit the config file here:              │
#  │ /root/.config/herbie/config.toml                │
#  ╰╥────────────────────────────────────────────────╯
#  👷🏻‍♂️
# /usr/local/lib/python3.10/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()
